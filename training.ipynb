# %% [markdown]
# Training model on dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dataset_engg.csv')
df.head()
# Out:
#    city_name    datetime  weather_code  temperature_2m_max  \
# 0          0  2020-01-01           3.0                25.5
# 1          0  2020-01-02           1.0                25.5
# 2          0  2020-01-03           1.0                24.5
# 3          0  2020-01-04           1.0                24.9
# 4          0  2020-01-05           0.0                25.0
#
#    temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                15.5                 20.0                      25.8
# 1                14.0                 19.5                      26.4
# 2                13.0                 18.0                      23.7
# 3                12.9                 18.1                      23.7
# 4                12.7                 18.6                      22.4
#
#    apparent_temperature_min  apparent_temperature_mean  daylight_duration  \
# 0                      13.7                       19.6           38688.66
# 1                      13.4                       19.1           38709.35
# 2                      12.1                       17.3           38731.80
# 3                      11.5                       16.7           38755.96
# 4                      11.3                       16.7           38781.81
#
#    ...  precipitation_hours  wind_speed_10m_max  wind_gusts_10m_max  \
# 0  ...                  0.0                16.0                31.3
# 1  ...                  0.0                13.8                27.4
# 2  ...                  0.0                10.5                23.4
# 3  ...                  0.0                12.5                26.6
# 4  ...                  0.0                16.6                34.2
#
#    wind_direction_10m_dominant  shortwave_radiation_sum  \
# 0                         48.0                    13.63
# 1                         21.0                    14.82
# 2                          7.0                    15.37
# 3                         50.0                    15.58
# 4                         75.0                    15.81
#
#    et0_fao_evapotranspiration  year  month        date  dayofweek
# 0                        3.15  2020      1  2020-01-01          2
# 1                        3.20  2020      1  2020-01-02          3
# 2                        3.09  2020      1  2020-01-03          4
# 3                        3.49  2020      1  2020-01-04          5
# 4                        3.82  2020      1  2020-01-05          6
#
# [5 rows x 24 columns]

# %% [markdown]
# Droping features ->
# datetime,
# snowfall_sum,
# wind_direction_10m_dominant

# %%
X = df.drop(['datetime', 'snowfall_sum', 'wind_direction_10m_dominant', 'date'], axis = 1)
Y = df['temperature_2m_mean']

X_train, X_test, Y_train, Y_test =train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %% [markdown]
# Training through Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators = 100, random_state = 42)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# Testing model

# %%
from sklearn.metrics import mean_absolute_error

Y_pred = model.predict(X_test)
mae = mean_absolute_error(Y_test, Y_pred)
print('Mean absolute error:', mae)
# Out:
# Mean absolute error: 0.00019687854714600244
