# %% [markdown]
# Feature Engineering

# %%
import pandas as pd
df = pd.read_csv('cleaned_dataset.csv')
df.head()
# Out:
#    city_name    datetime  weather_code  temperature_2m_max  \
# 0  Ahmedabad  2020-01-01           3.0                25.5
# 1  Ahmedabad  2020-01-02           1.0                25.5
# 2  Ahmedabad  2020-01-03           1.0                24.5
# 3  Ahmedabad  2020-01-04           1.0                24.9
# 4  Ahmedabad  2020-01-05           0.0                25.0
#
#    temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                15.5                 20.0                      25.8
# 1                14.0                 19.5                      26.4
# 2                13.0                 18.0                      23.7
# 3                12.9                 18.1                      23.7
# 4                12.7                 18.6                      22.4
#
#    apparent_temperature_min  apparent_temperature_mean  daylight_duration  \
# 0                      13.7                       19.6           38688.66
# 1                      13.4                       19.1           38709.35
# 2                      12.1                       17.3           38731.80
# 3                      11.5                       16.7           38755.96
# 4                      11.3                       16.7           38781.81
#
#    sunshine_duration  precipitation_sum  rain_sum  snowfall_sum  \
# 0           31785.50                0.0       0.0           0.0
# 1           35113.61                0.0       0.0           0.0
# 2           35096.95                0.0       0.0           0.0
# 3           35081.52                0.0       0.0           0.0
# 4           35078.90                0.0       0.0           0.0
#
#    precipitation_hours  wind_speed_10m_max  wind_gusts_10m_max  \
# 0                  0.0                16.0                31.3
# 1                  0.0                13.8                27.4
# 2                  0.0                10.5                23.4
# 3                  0.0                12.5                26.6
# 4                  0.0                16.6                34.2
#
#    wind_direction_10m_dominant  shortwave_radiation_sum  \
# 0                         48.0                    13.63
# 1                         21.0                    14.82
# 2                          7.0                    15.37
# 3                         50.0                    15.58
# 4                         75.0                    15.81
#
#    et0_fao_evapotranspiration
# 0                        3.15
# 1                        3.20
# 2                        3.09
# 3                        3.49
# 4                        3.82

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df['date'] = df['datetime'].dt.date
df['dayofweek'] = df['datetime'].dt.day_of_week
df.head()
# Out:
#    city_name   datetime  weather_code  temperature_2m_max  temperature_2m_min  \
# 0  Ahmedabad 2020-01-01           3.0                25.5                15.5
# 1  Ahmedabad 2020-01-02           1.0                25.5                14.0
# 2  Ahmedabad 2020-01-03           1.0                24.5                13.0
# 3  Ahmedabad 2020-01-04           1.0                24.9                12.9
# 4  Ahmedabad 2020-01-05           0.0                25.0                12.7
#
#    temperature_2m_mean  apparent_temperature_max  apparent_temperature_min  \
# 0                 20.0                      25.8                      13.7
# 1                 19.5                      26.4                      13.4
# 2                 18.0                      23.7                      12.1
# 3                 18.1                      23.7                      11.5
# 4                 18.6                      22.4                      11.3
#
#    apparent_temperature_mean  daylight_duration  ...  precipitation_hours  \
# 0                       19.6           38688.66  ...                  0.0
# 1                       19.1           38709.35  ...                  0.0
# 2                       17.3           38731.80  ...                  0.0
# 3                       16.7           38755.96  ...                  0.0
# 4                       16.7           38781.81  ...                  0.0
#
#    wind_speed_10m_max  wind_gusts_10m_max  wind_direction_10m_dominant  \
# 0                16.0                31.3                         48.0
# 1                13.8                27.4                         21.0
# 2                10.5                23.4                          7.0
# 3                12.5                26.6                         50.0
# 4                16.6                34.2                         75.0
#
#    shortwave_radiation_sum  et0_fao_evapotranspiration  year  month  \
# 0                    13.63                        3.15  2020      1
# 1                    14.82                        3.20  2020      1
# 2                    15.37                        3.09  2020      1
# 3                    15.58                        3.49  2020      1
# 4                    15.81                        3.82  2020      1
#
#          date  dayofweek
# 0  2020-01-01          2
# 1  2020-01-02          3
# 2  2020-01-03          4
# 3  2020-01-04          5
# 4  2020-01-05          6
#
# [5 rows x 24 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df["city_name"] = encoder.fit_transform(df["city_name"])

# %%
df.to_csv('dataset_engg.csv', index = False)
